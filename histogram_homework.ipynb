# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
download_url=("https://raw.githubusercontent.com/fivethirtyeight/"
   "data/master/college-majors/recent-grads.csv")
df=pd.read_csv(download_url)
type(df)
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1a6ce2362cd4> in <module>
# ----> 1 df.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %%
pd.set_option("display.max.columns",5)
pd.set_option("display.max.rows",10)
df.head()
# Out:
#    Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 0     1        2419  ...              364            193
# 1     2        2416  ...              257             50
# 2     3        2415  ...              176              0
# 3     4        2417  ...              102              0
# 4     5        2405  ...             4440            972
#
# [5 rows x 21 columns]

# %%
pd.set_option("display.max.columns",5)
pd.set_option("display.max.rows",None)
df.head()
# Out:
#    Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 0     1        2419  ...              364            193
# 1     2        2416  ...              257             50
# 2     3        2415  ...              176              0
# 3     4        2417  ...              102              0
# 4     5        2405  ...             4440            972
#
# [5 rows x 21 columns]

# %%
pd.set_option("display.max.columns",None)
pd.set_option("display.max.rows",5)
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# ...

# %%
top_5 = df.sort_values(by="Median", ascending=False).head()
top_5.plot(x="Major", y="Median", kind="bar", rot=5, fontsize=4)

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])

# %%
import matplotlib.pyplot as plt
plt.plot(df["Rank"], df["P25th"])

# %%
median_colomn.plot(kind="hist")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7774c8d732f3> in <module>
# ----> 1 median_colomn.plot(kind="hist")
#
# NameError: name 'median_colomn' is not defined

# %%
median_colomn=df["Median"]
median_colomn.plot(kind="hist")

# %%
top_5=df.sort_values(by='Median',ascending=False).head()
top_5.plot(x='Major',y='Median',kind='bar',rot=10,fontsize=10)

# %%
top_5=df.sort_values(by='Median',descending=True).head()
top_5.plot(x='Major',y='Median',kind='bar',rot=20,fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b3154708d5f5> in <module>
# ----> 1 top_5=df.sort_values(by='Median',descending=True).head()
#       2 top_5.plot(x='Major',y='Median',kind='bar',rot=20,fontsize=10)
#
# TypeError: sort_values() got an unexpected keyword argument 'descending'

# %%
top_5=df.sort_values(by='Median',descending=False).head()
top_5.plot(x='Major',y='Median',kind='bar',rot=20,fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-90461f6102e9> in <module>
# ----> 1 top_5=df.sort_values(by='Median',descending=False).head()
#       2 top_5.plot(x='Major',y='Median',kind='bar',rot=20,fontsize=10)
#
# TypeError: sort_values() got an unexpected keyword argument 'descending'

# %%
top_5=df.sort_values(by='Median',ascending=True).head()
top_5.plot(x='Major',y='Median',kind='bar',rot=20,fontsize=10)

# %%
top_5=df.sort_values(by='Median',ascending=True).head()
top_5.plot(x='Major',y='Median',kind='pie',rot=20,fontsize=10)

# %%
top_medians=df[df['Median']>60000].sort_values("Median")
##top_medians.plot(x="Major", y=["P25TH", "Median", "P75TH"], kind="bar",rot=12,fontsize=10)
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")

# %%
category_totals = df.groupby("Major_category")["Total"].sum().sort_values()

# %%
category_totals
# Out:
# Major_category
# Interdisciplinary                    12296.0
# Agriculture & Natural Resources      75620.0
#                                      ...
# Humanities & Liberal Arts           713468.0
# Business                           1302376.0
# Name: Total, Length: 16, dtype: float64

# %%
cat_totals.plot(kind='barh',fontsize=5).plot(kind='barh',fontsize=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8a7786a3ff04> in <module>
# ----> 1 cat_totals.plot(kind='barh',fontsize=5).plot(kind='barh',fontsize=5)
#
# NameError: name 'cat_totals' is not defined

# %%
category_totals.plot(kind='barh',fontsize=5).plot(kind='barh',fontsize=5)
# Out:
# []

# %%
category_totals.plot(kind='bar',fontsize=5).plot(kind='barh',fontsize=5)
# Out:
# []

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8389c35f58e2> in <module>
# ----> 1 small_cat_totals = cat_totals[cat_totals < 100_000]
#       2 big_cat_totals = cat_totals[cat_totals > 100_000]
#       3 small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
#       4 big_cat_totals = big_cat_totals.append(small_sums)
#       5 big_cat_totals.plot(kind="pie", label="")
#
# NameError: name 'cat_totals' is not defined

# %%
category_totals = df.groupby("Major_category")["Total"].sum().sort_values()

# %%
cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="")

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
small_cat_totals.plot(kind="pie", label="small_cat_total")
big_cat_totals.plot(kind="pie", label="big_cat_total")

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="big_cat_totals")

# %%
for i in range(5):
    plt.pie([15, 30, 25, 10,20],explode=(0, 0.05, 0, 0,0),colors=['yellow', 'green', 'red', 'blue','black'],autopct='%1.0f%%',
            shadow=False,startangle=90,radius=0.25,center=(0.5,0.5),frame=True,pctdistance=1.125)
    plt.axis('equal')
    plt.show()

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
small_cat_totals.plot(kind="pie", label="small_cat_totals")

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="big_cat_totals",labeldistance=1.2)

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="big_cat_totals",labeldistance=10)

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="big_cat_totals",labeldistance=2)

# %%
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="big_cat_totals",labeldistance=1.5)

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))
recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]
data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=8, weight="bold")
ax.set_title("Matplotlib bakery: A pie")
plt.show()

# %%
#C:\Users\Hasnat\Desktop\averages.csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as no

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_url=(r'C:\Users\Hasnat\Desktop\averages.csv')

# %%
data_frame=pd.read_csv(csv_url)

# %%
data_frame.head()
# Out:
#    congress chamber bioguide last_name state  district        party  votes  \
# 0         0   house  A000055  Aderholt    AL       4.0   Republican  176.0
# 1       115   house  A000055  Aderholt    AL       4.0            R   95.0
# 2       116   house  A000055  Aderholt    AL       4.0            R   81.0
# 3         0   house  A000367     Amash    MI       3.0  Independent  175.0
# 4       115   house  A000367     Amash    MI       3.0            R   96.0
#
#    agree_pct  predicted_agree  net_trump_vote
# 0   0.977273         0.956441            63.0
# 1   0.968421         0.946349            63.0
# 2   0.987654         0.968276            63.0
# 3   0.662857         0.745784             9.4
# 4   0.541667         0.847386             9.4

# %%
data_frame.plot()

# %%
df.plot(x="state", y="party")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7af26c9cf6f9> in <module>
# ----> 1 df.plot(x="state", y="party")
#
# NameError: name 'df' is not defined

# %%
data_frame.plot(x="state", y="party")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6502b41877db> in <module>
# ----> 1 data_frame.plot(x="state", y="party")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
# ...

# %%
data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"])

# %%
data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],type='pie')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3737960a0829> in <module>
# ----> 1 data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],type='pie')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],kind='pie')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-07821f25aa87> in <module>
# ----> 1 data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],kind='pie')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     804                     # converted to series actually. copy to not modify
#     805                     data = data[y].copy()
# --> 806                     data.index.name = y
#     807         elif isinstance(data, ABCDataFrame):
#     808             data_cols = data.columns
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in name(self, value)
#    1192                 "'MultiIndex.set_names' instead."
#    1193             )
# -> 1194         maybe_extract_name(value, None, type(self))
#    1195         self._name = value
#    1196
#
# ...

# %%
data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],type='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8f419ce22da4> in <module>
# ----> 1 data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],type='bar')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
data_frame.plot(x="net_trump_vote", y=["agree_pct","predicted_agree"],kind='bar')
